# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import cv2

from sklearn.preprocessing import StandardScaler, MinMaxScaler, LabelEncoder

from tensorflow.keras import Sequential
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[3], line 8
#       4 import cv2
#       6 from sklearn.preprocessing import StandardScaler, MinMaxScaler, LabelEncoder
# ----> 8 from tensorflow.keras import Sequential
#
# ModuleNotFoundError: No module named 'tensorflow'

# %%
import sys
import os

# Ajouter le chemin parent du dossier 'src'
sys.path.append(os.path.abspath('..'))


from src.data.loader import load_data
from src.data.preprocess import normalize, reshape_images

# Chemin corrigé
file_path = os.path.abspath("../../../../CV_dataset/train/train")

# Vérification (IMPORTANT)
print("Path:", file_path)
print("Exists:", os.path.exists(file_path))
# charger
train_data = load_data(file_path)


X = train_data[b'data']
y = train_data[b'fine_labels']

# preprocessing
X = reshape_images(X)
X = normalize(X)

print(X.shape)
print(X.min(), X.max())
